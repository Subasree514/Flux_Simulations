# %%
from __future__ import division, print_function, absolute_import
import csv
import pandas
from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)
import os
import xml.etree.ElementTree as etree
import cobra
import numpy as np
from itertools import chain
from cobra.util import solver as sutil
from cobra.core.solution import get_solution
from optlang.symbolics import add, Zero
import pandas as pd
import os
from os.path import join
import matplotlib.pyplot as plt
from cobra.medium import minimal_medium
# Press ⌃R to execute it or replace it with your code.
# Press Double ⇧ to search everywhere for classes, files, tool windows, actions, and settings.
from cobra.flux_analysis import production_envelope
from cobra import Model, Reaction, Metabolite
from cobra.flux_analysis import flux_variability_analysis
import matplotlib.pyplot as plt
from cobra.io import load_json_model, save_json_model, load_matlab_model, save_matlab_model, read_sbml_model, write_sbml_model
import math

# %%
## pareto
objective1={''}
objective2={''}
pareto_range = (0.0, 1.001)  # for some reason you need to pick a number higher than 1).
pareto_step_size = 0.01
analysis_type = 'pareto'
metric = 'manhattan'
rxn2avoid = {''}
primary=[]
solver='gurobi'
constants = {'deltaC_CO2': 0.0055, 'D_H2O_0': 2.13E-05, 'D_CO2_0': 1.33E-05, 'mid_day': 6, 'deltaT': 2,
             'FeasTol': 1e-03, 'OptTol': 1e-03}
def pareto_analysis(model, objective1=objective1, objective2=objective2, pareto_range=pareto_range, metric=metric,primary=primary):
    reaction_obj1 = model.reactions.get_by_id(objective1)
    reaction_obj2 = model.reactions.get_by_id(objective2)
    result_list = []
    solution_primary=[]
    model.objective = {}
    reaction_obj1.objective_coefficient = 1
    solution = model.optimize()
    print("\nSolving model (FBA) for determining objective 1 flux...")
    max_obj1 = dict(solution.fluxes)[objective1]
    print("Max {0}: {1}".format(objective1, max_obj1))
    # change objective
    reaction_obj1.objective_coefficient = 0
    reaction_obj2.objective_coefficient = 1
    print("\nSolving all iterations for Pareto frontier (FBA)...")
    for pareto in np.arange(pareto_range[0], pareto_range[1], pareto_step_size):
        if pareto == 1:
            reaction_obj1.lower_bound = max_obj1 * pareto  # * 0.999 # we need to add a bit of slack as the quadratic optimization is less accurate than the linear couterpart
        else:
            reaction_obj1.lower_bound = max_obj1 * pareto  # * 0.9999
        sol = model.optimize(objective_sense='maximize')
        # fix this minimal water loss value
        reaction_obj2.bounds = (sol.get_primal_by_id(objective2), sol.get_primal_by_id(objective2))
        if metric == 'manhattan':
            solution = cobra.flux_analysis.pfba(model)
            primary_dark=[]
            for i in model.reactions:
                primary_dark.append(i.id)
            solution_primary.append(solution.fluxes[primary_dark])
            reaction_obj2.bounds = (0, 1000.0)
        elif metric == 'euclidean':

            # make copy because that is easier that reverting all the solver settings
            copy_model = model.copy()
            model.solver = solver

            FeasTol = float(constants['FeasTol'])
            OptTol = float(constants['OptTol'])

            copy_model.solver.configuration.tolerances.feasibility = FeasTol
            copy_model.solver.configuration.tolerances.optimality = OptTol

            rxnlist = [r for r in copy_model.reactions if r.id not in rxn2avoid]

            obj_vars = chain.from_iterable([r.flux_expression ** 2] for r in rxnlist)
            copy_model.objective = copy_model.problem.Objective(add(obj_vars), direction='min')

            print('\nSolving quadratic minimisation of sum of fluxes')
            #print(solver)
            solution = copy_model.optimize(objective_sense=None)
            #result_list.append([pareto, solution[objective1], solution[objective2]])
        reaction_obj2.bounds = (0, 1000.0)
    #return result_list
    return solution_primary

# %%
## Plots
#model = cobra.io.load_matlab_model(join('/home/subasree/Desktop/Models_to_work/alpha_day_DM.mat'))
model_rs = cobra.io.load_matlab_model(join('alpha_day_RS_DM.mat'))
core_model=model_rs
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2586499
# Academic license - for non-commercial use only - expires 2025-11-18

# %%
core_model.metabolites.query('ATP')
# Out:
# [<Metabolite ATP_c at 0x7f11d349d9f0>,
#  <Metabolite ATP_m at 0x7f11d349da20>,
#  <Metabolite ATP_p at 0x7f11d349da50>,
#  <Metabolite ATP_x at 0x7f11d349da80>,
#  <Metabolite DATP_p at 0x7f11d349f070>,
#  <Metabolite PHOSPHORIBOSYL_ATP_p at 0x7f11d33128f0>,
#  <Metabolite DATP_c at 0x7f11d3369180>]

# %%
##Constraints
rubisco = core_model.problem.Constraint(3 * core_model.reactions.get_by_id("RXN_961_p").flux_expression - core_model.reactions.get_by_id("RIBULOSE_BISPHOSPHATE_CARBOXYLASE_RXN_p").flux_expression,lb=0, ub=0,)
core_model.add_cons_vars([rubisco])

atp_nadph_03 = core_model.problem.Constraint(3 * (core_model.reactions.get_by_id("NADPHoxm_tx").flux_expression + core_model.reactions.get_by_id("NADPHoxc_tx").flux_expression + core_model.reactions.get_by_id("NADPHoxp_tx").flux_expression) - core_model.reactions.get_by_id("ATPase_tx").flux_expression, lb=0, ub=0)
#core_model.add_cons_vars(atp_nadph_03)

# %%
## plot pareto plot
objective1 =  'DM_HYDROGEN_PEROXIDE_cell' #ho2_rad_p_demand AraCore_Biomass_tx DM_HS_cell DM_CPD0-1395_cell'DM_SUPER_OXIDE_cell'#'DM_NITRIC-OXIDE_cell'#'DM_CPD-12377_cell'#'DM_HYDROGEN_PEROXIDE_cell'
objective2 =  'AraCore_Biomass_tx'
solution_primary=pareto_analysis(core_model, objective1 = objective1, objective2=objective2, pareto_range = pareto_range, metric = metric)
#pd.DataFrame(result_list).to_excel('results.xlsx')
# Out:
# Solving model (FBA) for determining objective 1 flux...
# Max DM_HYDROGEN_PEROXIDE_cell: 150.0
#
# Solving all iterations for Pareto frontier (FBA)...

# %%
data=pd.DataFrame(solution_primary)
data_t=data.T
solution_frame=pd.DataFrame(data_t.iloc[:,0])
solution_frame.columns=['fluxes']

# %%
#Creating an empty dataframe
df_p = []
df_c = []
budget_metabolites = ["ATP_c", "ATP_m", "ATP_p", "ATP_x"]
compartment = ["_c", "_m", "_p", "_x"]

#budget_metabolites=["NADPH_c","NADPH_m","NADPH_p","NADPH_x","NADPH_v","NADPH_r","NADPH_e"]
#compartment = ["_c", "_m", "_p", "_x","_v","_r","_e"]

#budget_metabolites=["NADH_c","NADH_m","NADH_p","NADH_x","NADH_v","NADH_n"]
#compartment = ["_c", "_m", "_p", "_x","_v","_n"]
c3_model=core_model
for (a,com) in zip(budget_metabolites,compartment):
    i = c3_model.metabolites.get_by_id(a).summary()
    p = i.producing_flux
    c = i.consuming_flux

# Retrieving the reactions using pandas and filtering the transport reactions
    #producer = p.loc[:,"reaction"].str.contains(com)
    producer = p.loc[:,"reaction"].str.endswith(com) 
    producer_rs=p.loc[:,"reaction"].str.startswith("RS_")
    producer = p[producer]
    producer_rs=p[producer_rs]
    df_p.append(producer)
    df_p.append(producer_rs)
    producer_df = pd.concat(df_p)
        
# Retrieving the reactions using pandas
    consumer = c.loc[:,"reaction"].str.endswith(com)
    consumer_rs=c.loc[:,"reaction"].str.startswith("RS_")
    consumer = c[consumer]
    consumer_rs=c[consumer_rs]
    df_c.append(consumer)
    df_c.append(consumer_rs)
    consumer_df = pd.concat(df_c)
consumers=list(consumer_df['reaction'])
producers=list(producer_df.index)

# %%
consumers.append('ATPase_tx')
#consumers.extend(['NADPHoxc_tx','NADPHoxm_tx','NADPHoxp_tx'])
#consumers.extend(['NADH_DEHYDROG_A_RXN_mc','NADH_DEHYDROG_A_RXN_mi'])

# %%
def budget_plot(solution_frame, producers, consumers):
    
    #Get flux values from the simulation for metabolite consuming/producing reactions
    producers_df = solution_frame.loc[producers,:]
    consumers_df = solution_frame.loc[consumers,:]

    #Get values with negative flows: producing reactions with negative flow are consuming and vice-versa
    negative_producers = list(producers_df[producers_df["fluxes"] < 0].index)
    negative_consumers = list(consumers_df[consumers_df["fluxes"] < 0].index)


    #Add reactions to correct list
    consumers.extend(negative_producers)
    producers.extend(negative_consumers)

    #Remove reactions with negative flux from old list
    def remove_items(test_list, item):
        res = [i for i in test_list if i != item]
        return res

    for item in negative_producers:
        producers = remove_items(producers, item)

    for item in negative_consumers:
        consumers = remove_items(consumers, item)

    """
    Get producing reactions and fluxes
    """

    #Get flux values from the simulation for metabolite consuming/producing reactions (correct list)
    producers_df = solution_frame.loc[producers,:]
    #Make all values positive (disregard directionality)
    print(producers_df)
    producers_df["fluxes"] = producers_df["fluxes"].abs()
    #Remove reactions with zero flux
    producers_df = producers_df[(producers_df.T != 0).all()]
    producers_df


    """
    Get consuming reactions and fluxes
    """

    #Get flux values from the simulation for metabolite consuming/producing reactions (correct list)
    consumers_df = solution_frame.loc[consumers,:]
    print(consumers_df)
    #Make all values positive (disregard directionality)
    consumers_df["fluxes"]  = consumers_df["fluxes"].abs()
    #Remove reactions with zero flux3_P_SERINE_
    consumers_df = consumers_df[(consumers_df.T != 0).all()]
    consumers_df

    """
    Concatenate producer and consumer dataframes
    """

    producers_df["Status"] = "Producer"
    consumers_df["Status"] = "Consumer"

    frame = [producers_df, consumers_df]

    all_reactions = pd.concat(frame)

    all_reactions["label"] = all_reactions.index

    #Export full dataframe to csv
    #all_reactions.to_csv("budget_plot.csv", header=True)

    #Correct Budget stoichiometry
    atp_stoi=[]
    for i in all_reactions['label']:
        for met in budget_metabolites:
            try:
                rxn=c3_model.reactions.get_by_id(i).get_coefficient(met)
                atp_stoi.append(abs(rxn))
            except KeyError:
                continue

    new_flux = all_reactions["fluxes"] * atp_stoi

    all_reactions.insert(3,'coefficient', atp_stoi)
    print(all_reactions)
    all_reactions.insert(4,'new_flux', new_flux)
    print(all_reactions)
    """
    Fluxes in consumption and production should be equal
    """

    #Sum the flux values
    print("Sum of fluxes: {}".format(all_reactions.groupby(["Status"]).new_flux.sum()))

    """
    Pick the colors - using random
    """

    import random
    import matplotlib.pyplot as plt


    #Defining the nº of colors
    number_of_colors = len(all_reactions.index)

    #Getting a list of colors
    random.seed(177)
    color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
                for i in range(number_of_colors)]

    #Getting list of reactions
    reaction_list = list(all_reactions.index)

    #Build color dictionary
    color_dict = {}
    for i in range(len(reaction_list)):
        color_dict[reaction_list[i]] = color[i]

    """
    Plot the pivot table and barplot
    """
    fig = plt.figure()
    plt.style.use('fast')

    chart = all_reactions.pivot_table(index="Status", columns="label", values="new_flux")
    chart.plot.bar(rot = 0, stacked = True, legend = True, ylabel = "Flux", color = color_dict)
    plt.legend(loc='best', bbox_to_anchor=(1.0, 0.5, 0.5, 0.5), ncol = 2)
    #plt.title("Platoquinone Turnover in the Bundle Sheath Cell")
    figsize = [15, 20] #To prevent the cropping of the image
    fig.set_size_inches(w=100,h=70)
    fig.tight_layout()
    #plt.savefig('full_max_o2s.pdf')
    plt.show()
    chart

# %%
final_budget=budget_plot(solution_frame, producers, consumers)
# Out:
#                                  fluxes
# PEPDEPHOS_RXN_c                0.156767
# Mitochondrial_ATP_Synthase_m   5.666661
# SUCCCOASYN_RXN_m               0.000000
# CDPKIN_RXN_p                   0.000000
# PEPDEPHOS_RXN_p                0.410831
# Plastidial_ATP_Synthase_p     32.142857
#                                        fluxes
# 4_COUMARATE_COA_LIGASE_RXN_c         0.000000
# 6PFRUCTPHOS_RXN_c                    0.000000
# 6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_c  0.000000
# ADENOSINE_KINASE_RXN_c               0.000000
# ADENYL_KIN_RXN_c                     0.000000
# ...                                       ...
# RS_Plant_GSH_CP                      0.000000
# ACETATE_COA_LIGASE_RXN_x             0.426784
# A_B_oxidation_x                      0.000000
# Beta_Oxidation_x                     0.000000
# ATPase_tx                            0.000000
#
# [102 rows x 1 columns]
#                                       fluxes    Status  \
# PEPDEPHOS_RXN_c                     0.156767  Producer
# Mitochondrial_ATP_Synthase_m        5.666661  Producer
# PEPDEPHOS_RXN_p                     0.410831  Producer
# Plastidial_ATP_Synthase_p          32.142857  Producer
# ALANINE_TRNA_LIGASE_RXN_c           0.100858  Consumer
# ARGININE_TRNA_LIGASE_RXN_c          0.054996  Consumer
# ASNSYNA_RXN_c                       0.054006  Consumer
# ASPARAGINE_TRNA_LIGASE_RXN_c        0.054006  Consumer
# ASPARTATE_TRNA_LIGASE_RXN_c         0.054006  Consumer
# GDPKIN_RXN_c                        3.035166  Consumer
# GLURS_RXN_c                         0.065097  Consumer
# GLUTAMINE_TRNA_LIGASE_RXN_c         0.065097  Consumer
# GLYCINE_TRNA_LIGASE_RXN_c           0.045677  Consumer
# HISTIDINE_TRNA_LIGASE_RXN_c         0.017419  Consumer
# ISOLEUCINE_TRNA_LIGASE_RXN_c        0.036471  Consumer
# LEUCINE_TRNA_LIGASE_RXN_c           0.079474  Consumer
# LYSINE_TRNA_LIGASE_RXN_c            0.056706  Consumer
# METHIONINE_TRNA_LIGASE_RXN_c        0.024033  Consumer
# PHENYLALANINE_TRNA_LIGASE_RXN_c     0.052491  Consumer
# PROTON_ATPase_c                     4.739058  Consumer
# Protein_Processing_c                0.938192  Consumer
# Protein_Translocation_c             0.938192  Consumer
# SERINE_TRNA_LIGASE_RXN_c            0.080607  Consumer
# THREONINE_TRNA_LIGASE_RXN_c         0.045677  Consumer
# TYROSINE_TRNA_LIGASE_RXN_c          0.036575  Consumer
# UDPKIN_RXN_c                        0.282050  Consumer
# VALINE_TRNA_LIGASE_RXN_c            0.069001  Consumer
# ADENYL_KIN_RXN_m                    1.418982  Consumer
# GLUTAMINESYN_RXN_m                  4.619739  Consumer
# ACETATE__COA_LIGASE_RXN_p           1.467685  Consumer
# ACETYLGLUTKIN_RXN_p                 0.054996  Consumer
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p   1.193656  Consumer
# ADENYL_KIN_RXN_p                    1.581553  Consumer
# ARGSUCCINSYN_RXN_p                  0.054996  Consumer
# ASPARTATEKIN_RXN_p                  2.033323  Consumer
# ATPPHOSPHORIBOSYLTRANS_RXN_p        0.017419  Consumer
# CARBAMATE_KINASE_RXN_p              0.054996  Consumer
# GDPKIN_RXN_p                        0.017419  Consumer
# GLUC1PADENYLTRANS_RXN_p             0.163054  Consumer
# GLUTAMINESYN_RXN_p                  1.632408  Consumer
# GLY3KIN_RXN_p                       4.473648  Consumer
# HOMOSERKIN_RXN_p                    1.976617  Consumer
# PHOSGLYPHOS_RXN_p                  52.552824  Consumer
# PHOSPHORIBULOKINASE_RXN_p          29.434287  Consumer
# PRPPSYN_RXN_p                       0.017419  Consumer
# SHIKIMATE_KINASE_RXN_p              0.089066  Consumer
# SULFATE_ADENYLYLTRANS_RXN_p         0.024033  Consumer
# ACETATE_COA_LIGASE_RXN_x            0.426784  Consumer
#
#                                                                label  \
# PEPDEPHOS_RXN_c                                      PEPDEPHOS_RXN_c
# Mitochondrial_ATP_Synthase_m            Mitochondrial_ATP_Synthase_m
# PEPDEPHOS_RXN_p                                      PEPDEPHOS_RXN_p
# Plastidial_ATP_Synthase_p                  Plastidial_ATP_Synthase_p
# ALANINE_TRNA_LIGASE_RXN_c                  ALANINE_TRNA_LIGASE_RXN_c
# ARGININE_TRNA_LIGASE_RXN_c                ARGININE_TRNA_LIGASE_RXN_c
# ASNSYNA_RXN_c                                          ASNSYNA_RXN_c
# ASPARAGINE_TRNA_LIGASE_RXN_c            ASPARAGINE_TRNA_LIGASE_RXN_c
# ASPARTATE_TRNA_LIGASE_RXN_c              ASPARTATE_TRNA_LIGASE_RXN_c
# GDPKIN_RXN_c                                            GDPKIN_RXN_c
# GLURS_RXN_c                                              GLURS_RXN_c
# GLUTAMINE_TRNA_LIGASE_RXN_c              GLUTAMINE_TRNA_LIGASE_RXN_c
# GLYCINE_TRNA_LIGASE_RXN_c                  GLYCINE_TRNA_LIGASE_RXN_c
# HISTIDINE_TRNA_LIGASE_RXN_c              HISTIDINE_TRNA_LIGASE_RXN_c
# ISOLEUCINE_TRNA_LIGASE_RXN_c            ISOLEUCINE_TRNA_LIGASE_RXN_c
# LEUCINE_TRNA_LIGASE_RXN_c                  LEUCINE_TRNA_LIGASE_RXN_c
# LYSINE_TRNA_LIGASE_RXN_c                    LYSINE_TRNA_LIGASE_RXN_c
# METHIONINE_TRNA_LIGASE_RXN_c            METHIONINE_TRNA_LIGASE_RXN_c
# PHENYLALANINE_TRNA_LIGASE_RXN_c      PHENYLALANINE_TRNA_LIGASE_RXN_c
# PROTON_ATPase_c                                      PROTON_ATPase_c
# Protein_Processing_c                            Protein_Processing_c
# Protein_Translocation_c                      Protein_Translocation_c
# SERINE_TRNA_LIGASE_RXN_c                    SERINE_TRNA_LIGASE_RXN_c
# THREONINE_TRNA_LIGASE_RXN_c              THREONINE_TRNA_LIGASE_RXN_c
# TYROSINE_TRNA_LIGASE_RXN_c                TYROSINE_TRNA_LIGASE_RXN_c
# UDPKIN_RXN_c                                            UDPKIN_RXN_c
# VALINE_TRNA_LIGASE_RXN_c                    VALINE_TRNA_LIGASE_RXN_c
# ADENYL_KIN_RXN_m                                    ADENYL_KIN_RXN_m
# GLUTAMINESYN_RXN_m                                GLUTAMINESYN_RXN_m
# ACETATE__COA_LIGASE_RXN_p                  ACETATE__COA_LIGASE_RXN_p
# ACETYLGLUTKIN_RXN_p                              ACETYLGLUTKIN_RXN_p
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p  ACETYL_COA_CARBOXYLTRANSFER_RXN_p
# ADENYL_KIN_RXN_p                                    ADENYL_KIN_RXN_p
# ARGSUCCINSYN_RXN_p                                ARGSUCCINSYN_RXN_p
# ASPARTATEKIN_RXN_p                                ASPARTATEKIN_RXN_p
# ATPPHOSPHORIBOSYLTRANS_RXN_p            ATPPHOSPHORIBOSYLTRANS_RXN_p
# CARBAMATE_KINASE_RXN_p                        CARBAMATE_KINASE_RXN_p
# GDPKIN_RXN_p                                            GDPKIN_RXN_p
# GLUC1PADENYLTRANS_RXN_p                      GLUC1PADENYLTRANS_RXN_p
# GLUTAMINESYN_RXN_p                                GLUTAMINESYN_RXN_p
# GLY3KIN_RXN_p                                          GLY3KIN_RXN_p
# HOMOSERKIN_RXN_p                                    HOMOSERKIN_RXN_p
# PHOSGLYPHOS_RXN_p                                  PHOSGLYPHOS_RXN_p
# PHOSPHORIBULOKINASE_RXN_p                  PHOSPHORIBULOKINASE_RXN_p
# PRPPSYN_RXN_p                                          PRPPSYN_RXN_p
# SHIKIMATE_KINASE_RXN_p                        SHIKIMATE_KINASE_RXN_p
# SULFATE_ADENYLYLTRANS_RXN_p              SULFATE_ADENYLYLTRANS_RXN_p
# ACETATE_COA_LIGASE_RXN_x                    ACETATE_COA_LIGASE_RXN_x
#
#                                    coefficient
# PEPDEPHOS_RXN_c                          1.000
# Mitochondrial_ATP_Synthase_m             3.000
# PEPDEPHOS_RXN_p                          1.000
# Plastidial_ATP_Synthase_p                3.000
# ALANINE_TRNA_LIGASE_RXN_c                1.000
# ARGININE_TRNA_LIGASE_RXN_c               1.000
# ASNSYNA_RXN_c                            1.000
# ASPARAGINE_TRNA_LIGASE_RXN_c             1.000
# ASPARTATE_TRNA_LIGASE_RXN_c              1.000
# GDPKIN_RXN_c                             1.000
# GLURS_RXN_c                              1.000
# GLUTAMINE_TRNA_LIGASE_RXN_c              1.000
# GLYCINE_TRNA_LIGASE_RXN_c                1.000
# HISTIDINE_TRNA_LIGASE_RXN_c              1.000
# ISOLEUCINE_TRNA_LIGASE_RXN_c             1.000
# LEUCINE_TRNA_LIGASE_RXN_c                1.000
# LYSINE_TRNA_LIGASE_RXN_c                 1.000
# METHIONINE_TRNA_LIGASE_RXN_c             1.000
# PHENYLALANINE_TRNA_LIGASE_RXN_c          1.000
# PROTON_ATPase_c                          1.000
# Protein_Processing_c                     0.306
# Protein_Translocation_c                  1.445
# SERINE_TRNA_LIGASE_RXN_c                 1.000
# THREONINE_TRNA_LIGASE_RXN_c              1.000
# TYROSINE_TRNA_LIGASE_RXN_c               1.000
# UDPKIN_RXN_c                             1.000
# VALINE_TRNA_LIGASE_RXN_c                 1.000
# ADENYL_KIN_RXN_m                         1.000
# GLUTAMINESYN_RXN_m                       1.000
# ACETATE__COA_LIGASE_RXN_p                1.000
# ACETYLGLUTKIN_RXN_p                      1.000
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p        1.000
# ADENYL_KIN_RXN_p                         1.000
# ARGSUCCINSYN_RXN_p                       1.000
# ASPARTATEKIN_RXN_p                       1.000
# ATPPHOSPHORIBOSYLTRANS_RXN_p             1.000
# CARBAMATE_KINASE_RXN_p                   1.000
# GDPKIN_RXN_p                             1.000
# GLUC1PADENYLTRANS_RXN_p                  1.000
# GLUTAMINESYN_RXN_p                       1.000
# GLY3KIN_RXN_p                            1.000
# HOMOSERKIN_RXN_p                         1.000
# PHOSGLYPHOS_RXN_p                        1.000
# PHOSPHORIBULOKINASE_RXN_p                1.000
# PRPPSYN_RXN_p                            1.000
# SHIKIMATE_KINASE_RXN_p                   1.000
# SULFATE_ADENYLYLTRANS_RXN_p              1.000
# ACETATE_COA_LIGASE_RXN_x                 1.000
#                                       fluxes    Status  \
# PEPDEPHOS_RXN_c                     0.156767  Producer
# Mitochondrial_ATP_Synthase_m        5.666661  Producer
# PEPDEPHOS_RXN_p                     0.410831  Producer
# Plastidial_ATP_Synthase_p          32.142857  Producer
# ALANINE_TRNA_LIGASE_RXN_c           0.100858  Consumer
# ARGININE_TRNA_LIGASE_RXN_c          0.054996  Consumer
# ASNSYNA_RXN_c                       0.054006  Consumer
# ASPARAGINE_TRNA_LIGASE_RXN_c        0.054006  Consumer
# ASPARTATE_TRNA_LIGASE_RXN_c         0.054006  Consumer
# GDPKIN_RXN_c                        3.035166  Consumer
# GLURS_RXN_c                         0.065097  Consumer
# GLUTAMINE_TRNA_LIGASE_RXN_c         0.065097  Consumer
# GLYCINE_TRNA_LIGASE_RXN_c           0.045677  Consumer
# HISTIDINE_TRNA_LIGASE_RXN_c         0.017419  Consumer
# ISOLEUCINE_TRNA_LIGASE_RXN_c        0.036471  Consumer
# LEUCINE_TRNA_LIGASE_RXN_c           0.079474  Consumer
# LYSINE_TRNA_LIGASE_RXN_c            0.056706  Consumer
# METHIONINE_TRNA_LIGASE_RXN_c        0.024033  Consumer
# PHENYLALANINE_TRNA_LIGASE_RXN_c     0.052491  Consumer
# PROTON_ATPase_c                     4.739058  Consumer
# Protein_Processing_c                0.938192  Consumer
# Protein_Translocation_c             0.938192  Consumer
# SERINE_TRNA_LIGASE_RXN_c            0.080607  Consumer
# THREONINE_TRNA_LIGASE_RXN_c         0.045677  Consumer
# TYROSINE_TRNA_LIGASE_RXN_c          0.036575  Consumer
# UDPKIN_RXN_c                        0.282050  Consumer
# VALINE_TRNA_LIGASE_RXN_c            0.069001  Consumer
# ADENYL_KIN_RXN_m                    1.418982  Consumer
# GLUTAMINESYN_RXN_m                  4.619739  Consumer
# ACETATE__COA_LIGASE_RXN_p           1.467685  Consumer
# ACETYLGLUTKIN_RXN_p                 0.054996  Consumer
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p   1.193656  Consumer
# ADENYL_KIN_RXN_p                    1.581553  Consumer
# ARGSUCCINSYN_RXN_p                  0.054996  Consumer
# ASPARTATEKIN_RXN_p                  2.033323  Consumer
# ATPPHOSPHORIBOSYLTRANS_RXN_p        0.017419  Consumer
# CARBAMATE_KINASE_RXN_p              0.054996  Consumer
# GDPKIN_RXN_p                        0.017419  Consumer
# GLUC1PADENYLTRANS_RXN_p             0.163054  Consumer
# GLUTAMINESYN_RXN_p                  1.632408  Consumer
# GLY3KIN_RXN_p                       4.473648  Consumer
# HOMOSERKIN_RXN_p                    1.976617  Consumer
# PHOSGLYPHOS_RXN_p                  52.552824  Consumer
# PHOSPHORIBULOKINASE_RXN_p          29.434287  Consumer
# PRPPSYN_RXN_p                       0.017419  Consumer
# SHIKIMATE_KINASE_RXN_p              0.089066  Consumer
# SULFATE_ADENYLYLTRANS_RXN_p         0.024033  Consumer
# ACETATE_COA_LIGASE_RXN_x            0.426784  Consumer
#
#                                                                label  \
# PEPDEPHOS_RXN_c                                      PEPDEPHOS_RXN_c
# Mitochondrial_ATP_Synthase_m            Mitochondrial_ATP_Synthase_m
# PEPDEPHOS_RXN_p                                      PEPDEPHOS_RXN_p
# Plastidial_ATP_Synthase_p                  Plastidial_ATP_Synthase_p
# ALANINE_TRNA_LIGASE_RXN_c                  ALANINE_TRNA_LIGASE_RXN_c
# ARGININE_TRNA_LIGASE_RXN_c                ARGININE_TRNA_LIGASE_RXN_c
# ASNSYNA_RXN_c                                          ASNSYNA_RXN_c
# ASPARAGINE_TRNA_LIGASE_RXN_c            ASPARAGINE_TRNA_LIGASE_RXN_c
# ASPARTATE_TRNA_LIGASE_RXN_c              ASPARTATE_TRNA_LIGASE_RXN_c
# GDPKIN_RXN_c                                            GDPKIN_RXN_c
# GLURS_RXN_c                                              GLURS_RXN_c
# GLUTAMINE_TRNA_LIGASE_RXN_c              GLUTAMINE_TRNA_LIGASE_RXN_c
# GLYCINE_TRNA_LIGASE_RXN_c                  GLYCINE_TRNA_LIGASE_RXN_c
# HISTIDINE_TRNA_LIGASE_RXN_c              HISTIDINE_TRNA_LIGASE_RXN_c
# ISOLEUCINE_TRNA_LIGASE_RXN_c            ISOLEUCINE_TRNA_LIGASE_RXN_c
# LEUCINE_TRNA_LIGASE_RXN_c                  LEUCINE_TRNA_LIGASE_RXN_c
# LYSINE_TRNA_LIGASE_RXN_c                    LYSINE_TRNA_LIGASE_RXN_c
# METHIONINE_TRNA_LIGASE_RXN_c            METHIONINE_TRNA_LIGASE_RXN_c
# PHENYLALANINE_TRNA_LIGASE_RXN_c      PHENYLALANINE_TRNA_LIGASE_RXN_c
# PROTON_ATPase_c                                      PROTON_ATPase_c
# Protein_Processing_c                            Protein_Processing_c
# Protein_Translocation_c                      Protein_Translocation_c
# SERINE_TRNA_LIGASE_RXN_c                    SERINE_TRNA_LIGASE_RXN_c
# THREONINE_TRNA_LIGASE_RXN_c              THREONINE_TRNA_LIGASE_RXN_c
# TYROSINE_TRNA_LIGASE_RXN_c                TYROSINE_TRNA_LIGASE_RXN_c
# UDPKIN_RXN_c                                            UDPKIN_RXN_c
# VALINE_TRNA_LIGASE_RXN_c                    VALINE_TRNA_LIGASE_RXN_c
# ADENYL_KIN_RXN_m                                    ADENYL_KIN_RXN_m
# GLUTAMINESYN_RXN_m                                GLUTAMINESYN_RXN_m
# ACETATE__COA_LIGASE_RXN_p                  ACETATE__COA_LIGASE_RXN_p
# ACETYLGLUTKIN_RXN_p                              ACETYLGLUTKIN_RXN_p
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p  ACETYL_COA_CARBOXYLTRANSFER_RXN_p
# ADENYL_KIN_RXN_p                                    ADENYL_KIN_RXN_p
# ARGSUCCINSYN_RXN_p                                ARGSUCCINSYN_RXN_p
# ASPARTATEKIN_RXN_p                                ASPARTATEKIN_RXN_p
# ATPPHOSPHORIBOSYLTRANS_RXN_p            ATPPHOSPHORIBOSYLTRANS_RXN_p
# CARBAMATE_KINASE_RXN_p                        CARBAMATE_KINASE_RXN_p
# GDPKIN_RXN_p                                            GDPKIN_RXN_p
# GLUC1PADENYLTRANS_RXN_p                      GLUC1PADENYLTRANS_RXN_p
# GLUTAMINESYN_RXN_p                                GLUTAMINESYN_RXN_p
# GLY3KIN_RXN_p                                          GLY3KIN_RXN_p
# HOMOSERKIN_RXN_p                                    HOMOSERKIN_RXN_p
# PHOSGLYPHOS_RXN_p                                  PHOSGLYPHOS_RXN_p
# PHOSPHORIBULOKINASE_RXN_p                  PHOSPHORIBULOKINASE_RXN_p
# PRPPSYN_RXN_p                                          PRPPSYN_RXN_p
# SHIKIMATE_KINASE_RXN_p                        SHIKIMATE_KINASE_RXN_p
# SULFATE_ADENYLYLTRANS_RXN_p              SULFATE_ADENYLYLTRANS_RXN_p
# ACETATE_COA_LIGASE_RXN_x                    ACETATE_COA_LIGASE_RXN_x
#
#                                    coefficient   new_flux
# PEPDEPHOS_RXN_c                          1.000   0.156767
# Mitochondrial_ATP_Synthase_m             3.000  16.999983
# PEPDEPHOS_RXN_p                          1.000   0.410831
# Plastidial_ATP_Synthase_p                3.000  96.428571
# ALANINE_TRNA_LIGASE_RXN_c                1.000   0.100858
# ARGININE_TRNA_LIGASE_RXN_c               1.000   0.054996
# ASNSYNA_RXN_c                            1.000   0.054006
# ASPARAGINE_TRNA_LIGASE_RXN_c             1.000   0.054006
# ASPARTATE_TRNA_LIGASE_RXN_c              1.000   0.054006
# GDPKIN_RXN_c                             1.000   3.035166
# GLURS_RXN_c                              1.000   0.065097
# GLUTAMINE_TRNA_LIGASE_RXN_c              1.000   0.065097
# GLYCINE_TRNA_LIGASE_RXN_c                1.000   0.045677
# HISTIDINE_TRNA_LIGASE_RXN_c              1.000   0.017419
# ISOLEUCINE_TRNA_LIGASE_RXN_c             1.000   0.036471
# LEUCINE_TRNA_LIGASE_RXN_c                1.000   0.079474
# LYSINE_TRNA_LIGASE_RXN_c                 1.000   0.056706
# METHIONINE_TRNA_LIGASE_RXN_c             1.000   0.024033
# PHENYLALANINE_TRNA_LIGASE_RXN_c          1.000   0.052491
# PROTON_ATPase_c                          1.000   4.739058
# Protein_Processing_c                     0.306   0.287087
# Protein_Translocation_c                  1.445   1.355687
# SERINE_TRNA_LIGASE_RXN_c                 1.000   0.080607
# THREONINE_TRNA_LIGASE_RXN_c              1.000   0.045677
# TYROSINE_TRNA_LIGASE_RXN_c               1.000   0.036575
# UDPKIN_RXN_c                             1.000   0.282050
# VALINE_TRNA_LIGASE_RXN_c                 1.000   0.069001
# ADENYL_KIN_RXN_m                         1.000   1.418982
# GLUTAMINESYN_RXN_m                       1.000   4.619739
# ACETATE__COA_LIGASE_RXN_p                1.000   1.467685
# ACETYLGLUTKIN_RXN_p                      1.000   0.054996
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p        1.000   1.193656
# ADENYL_KIN_RXN_p                         1.000   1.581553
# ARGSUCCINSYN_RXN_p                       1.000   0.054996
# ASPARTATEKIN_RXN_p                       1.000   2.033323
# ATPPHOSPHORIBOSYLTRANS_RXN_p             1.000   0.017419
# CARBAMATE_KINASE_RXN_p                   1.000   0.054996
# GDPKIN_RXN_p                             1.000   0.017419
# GLUC1PADENYLTRANS_RXN_p                  1.000   0.163054
# GLUTAMINESYN_RXN_p                       1.000   1.632408
# GLY3KIN_RXN_p                            1.000   4.473648
# HOMOSERKIN_RXN_p                         1.000   1.976617
# PHOSGLYPHOS_RXN_p                        1.000  52.552824
# PHOSPHORIBULOKINASE_RXN_p                1.000  29.434287
# PRPPSYN_RXN_p                            1.000   0.017419
# SHIKIMATE_KINASE_RXN_p                   1.000   0.089066
# SULFATE_ADENYLYLTRANS_RXN_p              1.000   0.024033
# ACETATE_COA_LIGASE_RXN_x                 1.000   0.426784
# Sum of fluxes: Status
# Consumer    113.996153
# Producer    113.996153
# Name: new_flux, dtype: float64
